# %% [markdown]
# ### Graphs with nxGraph
# from Python

# %%
using PyPlot
using PyCall
@pyimport networkx as nx
# Out:
# INFO: Loading help data...

# %%
G=nx.star_graph(12)
pos=nx.spring_layout(G)
nx.draw(G,pos,node_color="#A0CBE2",width=4)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x12109ec50>)

# %%
petersen=nx.petersen_graph()
nx.draw(petersen)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1210e0890>)

# %%
tutte=nx.tutte_graph()
nx.draw(tutte)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1210fdf50>)

# %%
maze=nx.sedgewick_maze_graph()
nx.draw(maze)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x121c21d90>)
