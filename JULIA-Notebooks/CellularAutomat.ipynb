# %%
#Pkg.add("CellularAutomata")
using PyPlot
using PyCall
using CellularAutomata
# Out:
# INFO: Loading help data...

# %%
ca = CellularAutomaton(30, 128)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"hot")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119107b50>)
# PyObject None

# %%
ca = CellularAutomaton(110, 128)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"hot")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119656210>)
# PyObject None

# %%
ca = CellularAutomaton(137, 128)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"hot")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x118ed9b50>)
# PyObject None

# %%
ca = CellularAutomaton(107, 128)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"hot")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x117ffc390>)
# PyObject None

# %%
ca = CellularAutomaton(225, 128)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"hot")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1173d5390>)
# PyObject None

# %%
ca = CellularAutomaton(45, 1024)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"hot")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x115527590>)
# PyObject None

# %%
ca = CellularAutomaton(75, 256)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"hot")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119848850>)
# PyObject None

# %%
ca = CellularAutomaton(777, 256, k=3)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1196206d0>)
# PyObject None

# %%
ca = CellularAutomaton(1815, 256, k=3)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x117323450>)
# PyObject None

# %%
ca = CellularAutomaton(2049, 400, k=3)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11753c810>)
# PyObject None

# %%
ca = CellularAutomaton(1635, 4096, k=3)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1168ef4d0>)
# PyObject None

# %%
ca = CellularAutomaton(1635, 4096, k=3)
title("Cellular")
imgplot = imshow(ca.cells[3000:4000,3500:4500])
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1173c3050>)
# PyObject None

# %%
ca = CellularAutomaton(1635, 256, k=2)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1168ef990>)
# PyObject None

# %%
N = 256
v = rand(0:1,N)
ca = CellularAutomaton(105,v, N, k=2)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x117e06dd0>)
# PyObject None

# %%
N = 1256
v = rand(0:1,N)
Z = rand(0:10^20,1)
Z = 1947161326861202916
ca = CellularAutomaton(Z[1],v, N, k=6)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
#pycall(imgplot["set_cmap"],Any,"gray")
print(Z)
# Out:
# 1947161326861202916
# Figure(PyObject <matplotlib.figure.Figure object at 0x117966890>)

# %%
N = 512
v = rand(0:1,N)
Z = rand(0:10^20,1)
Z = 1947161326861202916
ca = CellularAutomaton(2007,v, N, k=3)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
print(Z)
# Out:
# 1947161326861202916
# Figure(PyObject <matplotlib.figure.Figure object at 0x139187fd0>)

# %%
N = 512
v = rand(0:1,N)
Z = rand(0:10^20,1)
Z = 1947161326861202916
ca = CellularAutomaton(2043,v, N, k=3)
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
print(Z)
# Out:
# 1947161326861202916
# Figure(PyObject <matplotlib.figure.Figure object at 0x1393c3a90>)

# %%
N = 4096
v = rand(0:1,N)
Z = rand(0:10^20,1)
Z = 1947161326861202916
ca = CellularAutomaton(2043,v, N, k=3)
figure(figsize=(36,36))
title("Cellular")
imgplot = imshow(ca.cells)
pycall(imgplot["set_interpolation"],Any,"nearest")
pycall(imgplot["set_cmap"],Any,"gray")
print(Z)
# Out:
# 1947161326861202916
# Figure(PyObject <matplotlib.figure.Figure object at 0x103167190>)
